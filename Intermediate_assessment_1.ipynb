# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
animal_df=pd.DataFrame(data,index=labels)
print(animal_df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
animal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
animal_df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
animal_df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
animal_df[['animal','age']].iloc[[3,4,8]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
animal_df[animal_df['visits']>3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
animal_df[animal_df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
animal_df[(animal_df['animal']=='cat')&(animal_df['age']<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
animal_df[(animal_df['age']>=2)&(animal_df['age']<=4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
animal_df.loc['f','age']=1.5
animal_df.iloc[[5]]
# Out:
#   animal  age  visits priority
# f    cat  1.5       3       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
animal_df['visits'].sum()
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
animal_df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
animal_df.loc['k','animal']='snake'
animal_df
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0      yes
# c  snake  0.5     2.0       no
# d    dog  NaN     3.0      yes
# e    dog  5.0     2.0       no
# f    cat  1.5     3.0       no
# g  snake  4.5     1.0       no
# h    cat  NaN     1.0      yes
# i    dog  7.0     2.0       no
# j    dog  3.0     1.0       no
# k  snake  NaN     NaN      NaN

# %%
animal_df=animal_df.drop('k',axis=0)
print(animal_df)
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0      yes
# c  snake  0.5     2.0       no
# d    dog  NaN     3.0      yes
# e    dog  5.0     2.0       no
# f    cat  1.5     3.0       no
# g  snake  4.5     1.0       no
# h    cat  NaN     1.0      yes
# i    dog  7.0     2.0       no
# j    dog  3.0     1.0       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
animal_df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
animal_df.sort_values(by=['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0     2.0       no
# e    dog  5.0     2.0       no
# g  snake  4.5     1.0       no
# j    dog  3.0     1.0       no
# b    cat  3.0     3.0      yes
# a    cat  2.5     1.0      yes
# f    cat  1.5     3.0       no
# c  snake  0.5     2.0       no
# h    cat  NaN     1.0      yes
# d    dog  NaN     3.0      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
animal_df['priority'] = animal_df['priority'].replace(['yes','no'],[True,False])
animal_df
# Out:
# <ipython-input-303-fd862099afac>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   animal_df['priority'] = animal_df['priority'].replace(['yes','no'],[True,False])
#   animal  age  visits  priority
# a    cat  2.5     1.0      True
# b    cat  3.0     3.0      True
# c  snake  0.5     2.0     False
# d    dog  NaN     3.0      True
# e    dog  5.0     2.0     False
# f    cat  1.5     3.0     False
# g  snake  4.5     1.0     False
# h    cat  NaN     1.0      True
# i    dog  7.0     2.0     False
# j    dog  3.0     1.0     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
animal_df['animal']=animal_df['animal'].replace('snake','python')
animal_df
# Out:
#    animal  age  visits  priority
# a     cat  2.5     1.0      True
# b     cat  3.0     3.0      True
# c  python  0.5     2.0     False
# d     dog  NaN     3.0      True
# e     dog  5.0     2.0     False
# f     cat  1.5     3.0     False
# g  python  4.5     1.0     False
# h     cat  NaN     1.0      True
# i     dog  7.0     2.0     False
# j     dog  3.0     1.0     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
ny_flights=pd.read_csv('/content/ny-flights.csv')
ny_flights.head(3)
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# 2  2014-01-01 22:24:00  2014-01-01 19:02:00

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
ny_flights['airline_id'].mode()
# Out:
# 0    20409
# Name: airline_id, dtype: int64

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
plt.scatter(ny_flights['dep_delay'],ny_flights['arr_delay'],c='red')
plt.xlabel('dep_delay')
plt.ylabel('arr_delay')
plt.title('Flight Delay ')
plt.show()
